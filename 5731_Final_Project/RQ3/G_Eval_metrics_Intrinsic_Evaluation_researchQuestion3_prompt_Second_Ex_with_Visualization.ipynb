# %% [markdown]
# <a href="https://colab.research.google.com/github/LavanyaPobbathi/Lavanya_INFO5731_Fall2023/blob/main/5731_Final_Project/RQ3/G_Eval_metrics_Intrinsic_Evaluation_researchQuestion3_prompt_Second_Ex_with_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rouge --quiet
# !pip install bert_score --quiet
# !pip install openai --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.5 MB/s eta 0:00:00

# %%
# !pip install --upgrade openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %% [markdown]
# #Second Experiment

# %%
import openai
import os
import re
import pandas as pd

# Python Implementation of the ROUGE Metric
from rouge import Rouge

# BERTScore leverages the pre-trained contextual embeddings from BERT and matches words in candidate and reference sentences by cosine similarity.
from bert_score import BERTScorer

openai.api_key = os.environ.get("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")

# %%
summary_Prompt1 = """

This patent describes a method and apparatus for capturing a dynamic sequence of images without physically moving the camera sensor. The process involves displaying a reference image, defining a trajectory between start and end positions, determining waypoints along the trajectory, and assigning a target image to each waypoint. Users can modify the trajectory shape and control the number of waypoints. Target image sizes are determined based on the initial and final images, transitioning gradually in size. The innovation lies in capturing diverse images without moving the camera physically, providing a user-friendly approach to defining sequences. The system has applications in panoramic playback and dynamic image sequences, offering flexibility and creative possibilities. The apparatus includes a camera sensor, display, and controller, with user input facilitated through a touch-sensitive display. The patent emphasizes user control over various parameters, such as trajectory shape, waypoint number, and target image format. The method enables capturing target images as separate images, portions of a single image, or frames of a video, all with common camera settings. Additionally, audio recording during image capture and playback as a sequence of distinct images over time enhances the user experience. Overall, this patent introduces an innovative and versatile approach to dynamic image capture and playback.
"""

# %%
summary_Prompt2 = """

This Google patent introduces a method and apparatus for capturing a sequence of uniquely framed target images without physically relocating the camera sensor. The process begins with displaying a reference image on a screen and identifying start and end positions within it. A trajectory is then determined between these positions, and target images are defined for waypoints along the trajectory. Notably, the system enables user control over the trajectory shape and the number of waypoints used. The target images can vary in size and format, and users can choose between single images, sequential images, or video formats. The patent emphasizes user interaction through touch-sensitive displays and introduces the concept of gradually transitioning target image sizes. Additionally, the apparatus comprises essential components such as a camera sensor, processor, and memory. The patent encompasses claims related to displaying the trajectory, user control over waypoints, determining target image sizes, capturing target images, integrating user input and display functions, and various playback and recording options. Overall, the invention provides a creative and efficient approach to capturing diverse image sequences without physical camera movement.
"""

# %%
summary_Prompt3 = """

Title: Google Patent Summary - Method and Apparatus for Image Control and Capture

Objective:
This Google patent introduces a novel method and apparatus for image control and capture, primarily targeted at camera sensors and devices with image capture capabilities. The main objectives of the patent are to provide users with enhanced control over image framing, define a sequence of differently framed target images, and facilitate dynamic image capture.

Innovations and Concepts:

User-Driven Image Control:

Users are empowered to define a sequence of target images by interacting with a reference image displayed on a screen.
They can specify start and end positions within the reference image and adjust the size and shape of the trajectory.
Dynamic Image Capture:

The patent introduces a groundbreaking concept where a sequence of differently framed target images is captured without physically moving the camera sensor.
Different portions of the sensor array are utilized to capture various target images, providing a zoom-like functionality.
Audio Recording:

The apparatus includes a microphone to record ambient audio while capturing the sequence of target images.
This audio can be synchronized and played back alongside the images, enhancing the overall user experience.
Playback Options:

The patent offers multiple playback options, allowing users to view the target images as a panorama or as a sequence of distinct images over time.
This flexibility enhances the creative and practical utility of the technology.
Touch-Sensitive Displays:

The patent suggests the use of touch-sensitive displays for seamless user interactions, simplifying the process of selecting image parameters.
Apparatus Configuration:

The apparatus comprises a display, a controller, and a camera sensor.
The controller manages user inputs, display functions, and camera settings to execute the defined image capture process.
Gradual Image Size Transition:

Target images along the trajectory transition smoothly between initial and final sizes while maintaining a consistent aspect ratio, ensuring visual coherence.
Image Format Selection:

Users can choose the format of the captured images, including single images, multiple sequential images, or videos, adding versatility to the technology.
Overall, this patent presents an innovative approach to image control and capture, enabling users to define and capture sequences of differently framed target images with ease and precision. The integration of dynamic image capture, audio recording, and flexible playback options enhances the capabilities of camera sensors and related devices, offering new possibilities for creative expression and practical applications.
"""

# %%
summary_Prompt4 = """
Title: Method and Apparatus for Image Capture and Trajectory Determination

Abstract:
The abstract of this Google patent describes the key objective of the invention, which is to generate a series of target images along a trajectory between a start position and an end position within a reference image displayed on a screen. The method aims to define specific target images at multiple waypoints along the trajectory, potentially for purposes like image processing or navigation.

Claims:

Claim 1 outlines the main steps of the method, including displaying a reference image, start and end positions, determining a trajectory, defining target images at waypoints, and capturing those target images with the camera sensor.

Claim 2 specifies the display of the determined trajectory on the screen.

Claim 3 focuses on enabling user control over the shape of the displayed trajectory.

Claim 4 involves displaying a plurality of waypoints on the screen.

Claim 5 enables user control over the number of waypoints used in the trajectory.

Claim 6 allows the user to select a format for the target images, including single image, sequential multiple images, or video.

Claim 7 discusses determining target image sizes for waypoints based on the initial and final target images, with gradual size transitions and a common aspect ratio.

Claim 8 explains how target images can be defined by capturing one or more images after determining the trajectory, with various options such as portions of a single captured image, separate automatically captured images, or frames of a captured video.

Claim 9 highlights the use of a touch-sensitive display for user interaction, including selecting start and end positions.

Claim 10 pertains to an apparatus with camera sensor, processor, and memory to perform the method described in Claim 1.

Claim 11 details an apparatus with camera sensor, display, and controller to perform the method described in Claim 1, including various user input and control options.

Claim 12 combines user input and display as a touch-sensitive display of a camera viewfinder.

Claim 13 specifies the controller's role in determining target image sizes for waypoints, emphasizing gradual transitions and a common aspect ratio between initial and final target image sizes.

Claim 14 mentions the controller's ability to determine target images by selecting portions of the reference image.

Claim 15 discusses the controller's capability to determine target images by controlling the capture of separate images for each target image.

Claim 16 focuses on the controller's control over the capture of separate images with common camera settings like focus, exposure, and white balance.

Claim 17 adds that the apparatus includes a microphone, and the controller can record audio while capturing images.

Claim 18 mentions the controller's ability to play back the defined target images as a sequence of distinct images over time.

Claim 19 specifies that each target image is a portion of the reference image.

Description Summary:
The patent's description explains the technology's purpose: to enable the generation of a sequence of differently framed target images without physically moving the camera. Users interact with an apparatus equipped with a camera sensor, display, and controller, primarily through a touch-sensitive display. The method involves displaying a reference image, setting start and end positions, determining a trajectory, and defining target images at waypoints. Users can control the trajectory shape, the number of waypoints, and the format of target images. Target image sizes transition gradually, maintaining a common aspect ratio. The innovation allows users to capture creatively framed images and videos without physically repositioning the camera. The captured images can be displayed together as a panorama or played back as a sequence, possibly with synchronized audio recording. This technology has applications in photography and videography, offering creative control to users without the need for physical camera movements.
"""

# %%
import openai
import pandas as pd

from openai import OpenAI

client = OpenAI(
    api_key="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"  # Replace with your actual API key
)

# Define the evaluation prompt template for Google patent summaries.
EVALUATION_PROMPT_TEMPLATE = """
You will be given one summary written for a Google patent. Your task is to rate the summary on one metric.
Please make sure you read and understand these instructions very carefully.
Please keep this document open while reviewing, and refer to it as needed.

Evaluation Criteria:

{criteria}

Evaluation Steps:

{steps}

Example:

Summary:

{summary}

Evaluation Form (scores ONLY):

- {metric_name}
"""

# Metric 1: Relevance

RELEVANCY_SCORE_CRITERIA = """
Relevance(1-5) - selection of important content from the source. \
The summary should include only important information from the source document. \
Annotators were instructed to penalize summaries which contained redundancies and excess information.
"""

RELEVANCY_SCORE_STEPS = """
1. Read the summary and the source document carefully.
2. Compare the summary to the source document and identify the main points of the article.
3. Assess how well the summary covers the main points of the article, and how much irrelevant or redundant information it contains.
4. Assign a relevance score from 1 to 5.
"""

# Metric 2: Coherence

COHERENCE_SCORE_CRITERIA = """
Coherence(1-5) - the collective quality of all sentences. \
We align this dimension with the DUC quality question of structure and coherence \
whereby "the summary should be well-structured and well-organized. \
The summary should not just be a heap of related information, but should build from sentence to a\
coherent body of information about a topic."
"""

COHERENCE_SCORE_STEPS = """
1. Read the Google patent carefully and identify the main topic and key points.
2. Read the summary and compare it to the Google patent. Check if the summary covers the main topic and key points of the Google patent,
and if it presents them in a clear and logical order.
3. Assign a score for coherence on a scale of 1 to 5, where 1 is the lowest and 5 is the highest based on the Evaluation Criteria.
"""

# Metric 3: Consistency

CONSISTENCY_SCORE_CRITERIA = """
Consistency(1-5) - the factual alignment between the summary and the summarized source. \
A factually consistent summary contains only statements that are entailed by the source document. \
Annotators were also asked to penalize summaries that contained hallucinated facts.
"""

CONSISTENCY_SCORE_STEPS = """
1. Read the Google patent carefully and identify the main facts and details it presents.
2. Read the summary and compare it to the Google patent. Check if the summary contains any factual errors that are not supported by the Google patent.
3. Assign a score for consistency based on the Evaluation Criteria.
"""

# Metric 4: Fluency

FLUENCY_SCORE_CRITERIA = """
Fluency(1-5): the quality of the summary in terms of grammar, spelling, punctuation, word choice, and sentence structure.
1: Poor. The summary has many errors that make it hard to understand or sound unnatural.
2: Fair. The summary has some errors that affect the clarity or smoothness of the text, but the main points are still comprehensible.
3: Good. The summary has few or no errors and is easy to read and follow.
"""

FLUENCY_SCORE_STEPS = """
Read the summary and evaluate its fluency based on the given criteria. Assign a fluency score from 1 to 5.
"""

# Define a function to get G-Eval scores using GPT-4.
def get_geval_score(criteria, steps, summary, metric_name):
    prompt = EVALUATION_PROMPT_TEMPLATE.format(
        criteria=criteria,
        steps=steps,
        metric_name=metric_name,
        summary=summary,
    )
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
        max_tokens=5,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
    )
    return response.choices[0].message.content


evaluation_metrics = {
    "Relevance": (RELEVANCY_SCORE_CRITERIA, RELEVANCY_SCORE_STEPS),
    "Coherence": (COHERENCE_SCORE_CRITERIA, COHERENCE_SCORE_STEPS),
    "Consistency": (CONSISTENCY_SCORE_CRITERIA, CONSISTENCY_SCORE_STEPS),
    "Fluency": (FLUENCY_SCORE_CRITERIA, FLUENCY_SCORE_STEPS),
}

# Define the summaries for each image.
summaries = {
    "GPT3.5 Sum2_Prompt1": summary_Prompt1,  # replace with your first summary
    "GPT3.5 Sum2_Prompt2": summary_Prompt2,  # replace with your second summary
    "GPT3.5 Sum2_Prompt3": summary_Prompt3,  # replace with your third summary
    "GPT3.5 Sum2_Prompt4": summary_Prompt4,  # replace with your fourth summary
}

# Initialize data for the DataFrame.
data = {"Evaluation Type": [], "Summary Type": [], "Score": []}

# Evaluate each summary for each metric.
for eval_type, (criteria, steps) in evaluation_metrics.items():
    for summ_type, summary in summaries.items():
        data["Evaluation Type"].append(eval_type)
        data["Summary Type"].append(summ_type)
        result = get_geval_score(criteria, steps, summary, eval_type)
        score_num = int(result.strip())
        data["Score"].append(score_num)

# Create a pivot table and display it.
pivot_df = pd.DataFrame(data, index=None).pivot(
    index="Evaluation Type", columns="Summary Type", values="Score"
)

def highlight_max(s):
    is_max = s == s.max()
    return [
        "background-color: lightgreen" if v else "background-color: white"
        for v in is_max
    ]

styled_pivot_df = pivot_df.style.apply(highlight_max, axis=1)
display(styled_pivot_df)
# Out:
# <style type="text/css">
# #T_eeff9_row0_col0, #T_eeff9_row0_col1, #T_eeff9_row1_col0, #T_eeff9_row3_col0, #T_eeff9_row3_col1, #T_eeff9_row3_col2 {
#   background-color: white;
# }
# #T_eeff9_row0_col2, #T_eeff9_row0_col3, #T_eeff9_row1_col1, #T_eeff9_row1_col2, #T_eeff9_row1_col3, #T_eeff9_row2_col0, #T_eeff9_row2_col1, #T_eeff9_row2_col2, #T_eeff9_row2_col3, #T_eeff9_row3_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eeff9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Summary Type</th>
#       <th id="T_eeff9_level0_col0" class="col_heading level0 col0" >GPT3.5 Sum2_Prompt1</th>
#       <th id="T_eeff9_level0_col1" class="col_heading level0 col1" >GPT3.5 Sum2_Prompt2</th>
#       <th id="T_eeff9_level0_col2" class="col_heading level0 col2" >GPT3.5 Sum2_Prompt3</th>
#       <th id="T_eeff9_level0_col3" class="col_heading level0 col3" >GPT3.5 Sum2_Prompt4</th>
#     </tr>
#     <tr>
# ...

# %%
import openai
from openai import OpenAI

client = OpenAI(
    api_key="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"  # Replace with your actual API key
)

def evaluate_text(text):
    criteria = ["Fluency", "Coherence", "Informativeness", "Abstraction", "Consistency"]
    scores = {}
    for criterion in criteria:
        prompt = f"Please evaluate the following text based on {criterion} on a scale from 0 to 10 (provide only score):\n\n{text}"
        response = client.chat.completions.create(
            model="gpt-4",
            messages=[{"role": "user", "content": prompt}],
            temperature=0,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
        )
        score = response.choices[0].message.content.strip()
        scores[criterion] = score
    return scores

prompt1 = """

This patent describes a method and apparatus for capturing a dynamic sequence of images without physically moving the camera sensor. The process involves displaying a reference image, defining a trajectory between start and end positions, determining waypoints along the trajectory, and assigning a target image to each waypoint. Users can modify the trajectory shape and control the number of waypoints. Target image sizes are determined based on the initial and final images, transitioning gradually in size. The innovation lies in capturing diverse images without moving the camera physically, providing a user-friendly approach to defining sequences. The system has applications in panoramic playback and dynamic image sequences, offering flexibility and creative possibilities. The apparatus includes a camera sensor, display, and controller, with user input facilitated through a touch-sensitive display. The patent emphasizes user control over various parameters, such as trajectory shape, waypoint number, and target image format. The method enables capturing target images as separate images, portions of a single image, or frames of a video, all with common camera settings. Additionally, audio recording during image capture and playback as a sequence of distinct images over time enhances the user experience. Overall, this patent introduces an innovative and versatile approach to dynamic image capture and playback.
"""
scores = evaluate_text(prompt1)
print("GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt1")
for criterion, score in scores.items():
    print(f"{criterion}: {score}")

print("\n\n")

prompt2 = """

This Google patent introduces a method and apparatus for capturing a sequence of uniquely framed target images without physically relocating the camera sensor. The process begins with displaying a reference image on a screen and identifying start and end positions within it. A trajectory is then determined between these positions, and target images are defined for waypoints along the trajectory. Notably, the system enables user control over the trajectory shape and the number of waypoints used. The target images can vary in size and format, and users can choose between single images, sequential images, or video formats. The patent emphasizes user interaction through touch-sensitive displays and introduces the concept of gradually transitioning target image sizes. Additionally, the apparatus comprises essential components such as a camera sensor, processor, and memory. The patent encompasses claims related to displaying the trajectory, user control over waypoints, determining target image sizes, capturing target images, integrating user input and display functions, and various playback and recording options. Overall, the invention provides a creative and efficient approach to capturing diverse image sequences without physical camera movement.
"""
scores = evaluate_text(prompt2)
print("GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt2")
for criterion, score in scores.items():
    print(f"{criterion}: {score}")

print("\n\n")


prompt3 = """

Title: Google Patent Summary - Method and Apparatus for Image Control and Capture

Objective:
This Google patent introduces a novel method and apparatus for image control and capture, primarily targeted at camera sensors and devices with image capture capabilities. The main objectives of the patent are to provide users with enhanced control over image framing, define a sequence of differently framed target images, and facilitate dynamic image capture.

Innovations and Concepts:

User-Driven Image Control:

Users are empowered to define a sequence of target images by interacting with a reference image displayed on a screen.
They can specify start and end positions within the reference image and adjust the size and shape of the trajectory.
Dynamic Image Capture:

The patent introduces a groundbreaking concept where a sequence of differently framed target images is captured without physically moving the camera sensor.
Different portions of the sensor array are utilized to capture various target images, providing a zoom-like functionality.
Audio Recording:

The apparatus includes a microphone to record ambient audio while capturing the sequence of target images.
This audio can be synchronized and played back alongside the images, enhancing the overall user experience.
Playback Options:

The patent offers multiple playback options, allowing users to view the target images as a panorama or as a sequence of distinct images over time.
This flexibility enhances the creative and practical utility of the technology.
Touch-Sensitive Displays:

The patent suggests the use of touch-sensitive displays for seamless user interactions, simplifying the process of selecting image parameters.
Apparatus Configuration:

The apparatus comprises a display, a controller, and a camera sensor.
The controller manages user inputs, display functions, and camera settings to execute the defined image capture process.
Gradual Image Size Transition:

Target images along the trajectory transition smoothly between initial and final sizes while maintaining a consistent aspect ratio, ensuring visual coherence.
Image Format Selection:

Users can choose the format of the captured images, including single images, multiple sequential images, or videos, adding versatility to the technology.
Overall, this patent presents an innovative approach to image control and capture, enabling users to define and capture sequences of differently framed target images with ease and precision. The integration of dynamic image capture, audio recording, and flexible playback options enhances the capabilities of camera sensors and related devices, offering new possibilities for creative expression and practical applications.
"""

scores = evaluate_text(prompt3)
print("GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt3")
for criterion, score in scores.items():
    print(f"{criterion}: {score}")

print("\n\n")

prompt4 =  """
Title: Method and Apparatus for Image Capture and Trajectory Determination

Abstract:
The abstract of this Google patent describes the key objective of the invention, which is to generate a series of target images along a trajectory between a start position and an end position within a reference image displayed on a screen. The method aims to define specific target images at multiple waypoints along the trajectory, potentially for purposes like image processing or navigation.

Claims:

Claim 1 outlines the main steps of the method, including displaying a reference image, start and end positions, determining a trajectory, defining target images at waypoints, and capturing those target images with the camera sensor.

Claim 2 specifies the display of the determined trajectory on the screen.

Claim 3 focuses on enabling user control over the shape of the displayed trajectory.

Claim 4 involves displaying a plurality of waypoints on the screen.

Claim 5 enables user control over the number of waypoints used in the trajectory.

Claim 6 allows the user to select a format for the target images, including single image, sequential multiple images, or video.

Claim 7 discusses determining target image sizes for waypoints based on the initial and final target images, with gradual size transitions and a common aspect ratio.

Claim 8 explains how target images can be defined by capturing one or more images after determining the trajectory, with various options such as portions of a single captured image, separate automatically captured images, or frames of a captured video.

Claim 9 highlights the use of a touch-sensitive display for user interaction, including selecting start and end positions.

Claim 10 pertains to an apparatus with camera sensor, processor, and memory to perform the method described in Claim 1.

Claim 11 details an apparatus with camera sensor, display, and controller to perform the method described in Claim 1, including various user input and control options.

Claim 12 combines user input and display as a touch-sensitive display of a camera viewfinder.

Claim 13 specifies the controller's role in determining target image sizes for waypoints, emphasizing gradual transitions and a common aspect ratio between initial and final target image sizes.

Claim 14 mentions the controller's ability to determine target images by selecting portions of the reference image.

Claim 15 discusses the controller's capability to determine target images by controlling the capture of separate images for each target image.

Claim 16 focuses on the controller's control over the capture of separate images with common camera settings like focus, exposure, and white balance.

Claim 17 adds that the apparatus includes a microphone, and the controller can record audio while capturing images.

Claim 18 mentions the controller's ability to play back the defined target images as a sequence of distinct images over time.

Claim 19 specifies that each target image is a portion of the reference image.

Description Summary:
The patent's description explains the technology's purpose: to enable the generation of a sequence of differently framed target images without physically moving the camera. Users interact with an apparatus equipped with a camera sensor, display, and controller, primarily through a touch-sensitive display. The method involves displaying a reference image, setting start and end positions, determining a trajectory, and defining target images at waypoints. Users can control the trajectory shape, the number of waypoints, and the format of target images. Target image sizes transition gradually, maintaining a common aspect ratio. The innovation allows users to capture creatively framed images and videos without physically repositioning the camera. The captured images can be displayed together as a panorama or played back as a sequence, possibly with synchronized audio recording. This technology has applications in photography and videography, offering creative control to users without the need for physical camera movements.
"""
print("\n\n")

scores = evaluate_text(prompt4)
print("GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt4")
for criterion, score in scores.items():
    print(f"{criterion}: {score}")
# Out:
# GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt1
# Fluency: 10
# Coherence: 10
# Informativeness: 10
# Abstraction: 5.5
# Consistency: 10
#
#
#
# GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt2
# Fluency: 10
# Coherence: 10
# Informativeness: 10
# Abstraction: 5.5
# Consistency: 10
#
#
#
# GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt3
# Fluency: 10
# Coherence: 10
# Informativeness: 10
# Abstraction: 5.5
# Consistency: 10
#
#
#
#
#
#
# GPT3.5 Intrinsic Evaluation Scores for Final Summary2 prompt4
# Fluency: 10
# Coherence: 10
# Informativeness: 10
# Abstraction: 7.5
# Consistency: 10

# %% [markdown]
# #Visualization the results

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Experiment 1
categories = ['Coherence', 'Consistency', 'Fluency', 'Relevance']
exp1_prompt1 = [5, 5, 4, 4]
exp1_prompt2 = [5, 5, 4, 5]
exp1_prompt3 = [5, 4, 4, 5]
exp1_prompt4 = [4, 4, 4, 4]

bar_width = 0.2
index = np.arange(len(categories))

# Custom colors
colors = ['lightblue', 'lightgreen', 'lightcoral', 'plum']


# Plotting for Experiment 1
plt.figure(figsize=(12, 6))
plt.bar(index, exp1_prompt1, bar_width, color=colors[0], label='Prompt 1')
plt.bar(index + bar_width, exp1_prompt2, bar_width, color=colors[1], label='Prompt 2')
plt.bar(index + 2 * bar_width, exp1_prompt3, bar_width, color=colors[2], label='Prompt 3')
plt.bar(index + 3 * bar_width, exp1_prompt4, bar_width, color=colors[3], label='Prompt 4')

plt.xlabel('Evaluation Type')
plt.ylabel('Scores')
plt.title('Experiment 1: Customized Prompt Evaluation Metrics')
plt.xticks(index + bar_width, categories)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Experiment 2
exp2_prompt1 = [4, 4, 4, 4]
exp2_prompt2 = [4, 5, 4, 4]
exp2_prompt3 = [5, 5, 4, 4]
exp2_prompt4 = [5, 5, 4, 5]

categories = ['Coherence', 'Consistency', 'Fluency', 'Relevance']
bar_width = 0.2
index = np.arange(len(categories))

# Custom colors for Experiment 2
colors_exp2 = ['peachpuff', 'palegreen', 'lightskyblue', 'brown']

# Plotting for Experiment 2
plt.figure(figsize=(12, 6))
plt.bar(index, exp2_prompt1, bar_width, color=colors_exp2[0], label='Prompt 1')
plt.bar(index + bar_width, exp2_prompt2, bar_width, color=colors_exp2[1], label='Prompt 2')
plt.bar(index + 2 * bar_width, exp2_prompt3, bar_width, color=colors_exp2[2], label='Prompt 3')
plt.bar(index + 3 * bar_width, exp2_prompt4, bar_width, color=colors_exp2[3], label='Prompt 4')

plt.xlabel('Evaluation Type')
plt.ylabel('Scores')
plt.title('Experiment 2: Customized Prompt Evaluation Metrics')
plt.xticks(index + bar_width, categories)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Experiment 1
exp1_fluency = [8.5, 8.5, 9.5, 8.5]
exp1_coherence = [8.5, 8.5, 8.5, 8.5]
exp1_informativeness = [9.5, 9.5, 9.5, 8]
exp1_abstraction = [8.5, 8.5, 8.5, 8.5]
exp1_consistency = [8.5, 8.5, 8.5, 8.5]

# Data for Experiment 2
exp2_fluency = [10, 10, 10, 10]
exp2_coherence = [10, 10, 10, 10]
exp2_informativeness = [10, 10, 10, 10]
exp2_abstraction = [5.5, 5.5, 5.5, 7.5]
exp2_consistency = [10, 10, 10, 10]

prompt_numbers = [1, 2, 3, 4]

# Plotting for Experiment
"""
plt.figure(figsize=(14, 6))
plt.plot(prompt_numbers, exp1_fluency, marker='o', label='Fluency')
plt.plot(prompt_numbers, exp1_coherence, marker='o', label='Coherence')
plt.plot(prompt_numbers, exp1_informativeness, marker='o', label='Informativeness')
plt.plot(prompt_numbers, exp1_abstraction, marker='o', label='Abstraction')
plt.plot(prompt_numbers, exp1_consistency, marker='o', label='Consistency')

plt.xlabel('Prompt Number')
plt.ylabel('Scores')
plt.title('Experiment 1: Intrinsic Evaluation Scores')
plt.xticks(prompt_numbers)
plt.legend()
plt.grid(True)
plt.show()
"""
# Plotting for Experiment 2 with different line styles and annotations
plt.figure(figsize=(14, 6))

# Using different line styles and markers
plt.plot(prompt_numbers, exp1_fluency, marker='o', linestyle='-', label='Fluency')
plt.plot(prompt_numbers, exp1_coherence, marker='s', linestyle='--', label='Coherence')
plt.plot(prompt_numbers, exp1_informativeness, marker='^', linestyle='-.', label='Informativeness')
plt.plot(prompt_numbers, exp1_abstraction, marker='d', linestyle=':', label='Abstraction')
plt.plot(prompt_numbers, exp1_consistency, marker='x', linestyle='-', label='Consistency')

plt.xlabel('Prompt Number')
plt.ylabel('Scores')
plt.title('Experiment 1: Intrinsic Evaluation Scores')
plt.xticks(prompt_numbers)

# Adding annotations
for i, txt in enumerate(exp1_abstraction):
    plt.annotate(f'Abstraction: {txt}', (prompt_numbers[i], exp1_abstraction[i]), textcoords="offset points", xytext=(0,10), ha='center')

plt.legend()
plt.grid(True)
plt.show()

# Plotting for Experiment 2
# Stacked Bar Chart for Experiment 2

# Creating a figure
plt.figure(figsize=(12, 6))

# Stacking each score
plt.bar(prompt_numbers, exp2_fluency, label='Fluency', color='skyblue')
plt.bar(prompt_numbers, exp2_coherence, bottom=exp2_fluency, label='Coherence', color='lightgreen')
plt.bar(prompt_numbers, exp2_informativeness, bottom=np.array(exp2_fluency)+np.array(exp2_coherence), label='Informativeness', color='salmon')
plt.bar(prompt_numbers, exp2_abstraction, bottom=np.array(exp2_fluency)+np.array(exp2_coherence)+np.array(exp2_informativeness), label='Abstraction', color='orchid')
plt.bar(prompt_numbers, exp2_consistency, bottom=np.array(exp2_fluency)+np.array(exp2_coherence)+np.array(exp2_informativeness)+np.array(exp2_abstraction), label='Consistency', color='gold')

plt.xlabel('Prompt Number')
plt.ylabel('Total Scores')
plt.title('Experiment 2: Stacked Scores by Category')
plt.xticks(prompt_numbers)
plt.legend()
plt.show()
